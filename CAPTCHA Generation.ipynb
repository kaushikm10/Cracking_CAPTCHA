# %%
cd drive/MyDrive/Colab Notebooks/CAPTCHA Cracking using CNN
# Out:
# /content/drive/MyDrive/Colab Notebooks/CAPTCHA Cracking using CNN

# %%
# !mkdir images

# %%
cd images
# Out:
# /content/drive/MyDrive/Colab Notebooks/CAPTCHA Cracking using CNN/images

# %%
# !mkdir train

# %%
# !mkdir test

# %%
cd train
# Out:
# /content/drive/MyDrive/Colab Notebooks/CAPTCHA Cracking using CNN/images/train

# %%
import random
import string
import matplotlib.pyplot as plt
from captcha.image import ImageCaptcha
import cv2
import time
count = 0
#no = 5000   #for train images
no = 500   # for test images
filenames = []
lower = list(string.ascii_lowercase)
while count < no:
      x = True
      while x:
        length = 5
        captcha = ""
        for i in range(length):
          captcha = captcha + lower[random.randint(0, 25)]
        if captcha in filenames:
          continue
        else:
          x = False
          filenames.append(captcha)
      image = ImageCaptcha()
      data = image.generate(captcha)
      image.write(captcha, f'{captcha}.png')
      count += 1
      if count%50 == 0:
        print(count, " CAPTCHAs generated")
# Out:
# 50  CAPTCHAs generated
# 100  CAPTCHAs generated
# 150  CAPTCHAs generated
# 200  CAPTCHAs generated
# 250  CAPTCHAs generated
# 300  CAPTCHAs generated
# 350  CAPTCHAs generated
# 400  CAPTCHAs generated
# 450  CAPTCHAs generated
# 500  CAPTCHAs generated

# %%
cd ..
# Out:
# /content/drive/My Drive/Colab Notebooks/CAPTCHA Cracking using CNN/images

# %%
cd test
# Out:
# /content/drive/My Drive/Colab Notebooks/CAPTCHA Cracking using CNN/images/test

# %%
pwd
# Out:
# '/content/drive/My Drive/Colab Notebooks/CAPTCHA Cracking using CNN/images/test'

# %%
ls
# Out:
# aabos.png  dzjbx.png  ibzkn.png  kzzfk.png  pdrpg.png  syfzf.png  wqvdr.png
# aamhm.png  dznkr.png  iccyb.png  lcqff.png  pezmx.png  szdkm.png  wsocl.png
# aatxy.png  eacrb.png  iclhb.png  ldrda.png  plomr.png  szkyh.png  wsxcp.png
# adzjb.png  eapxh.png  icxlq.png  ldvbs.png  plwag.png  tcutx.png  wtndu.png
# aelcu.png  eauoy.png  idhxy.png  lhzde.png  pmzfd.png  tdqjy.png  wubty.png
# agqos.png  echrq.png  igvcz.png  liezl.png  pnwny.png  tdrug.png  wxgap.png
# agtzi.png  eckaq.png  ihxbq.png  linbg.png  poexs.png  thruk.png  wxpiw.png
# ahojc.png  ecvjb.png  iiqvi.png  ljfwq.png  ppcsy.png  tjdqg.png  wxvxn.png
# aiuio.png  efcns.png  iiuuf.png  lkqzr.png  ppmzs.png  tkcrk.png  wygkq.png
# ajwyc.png  eflzv.png  ijbod.png  lnqea.png  prxuo.png  tlttt.png  xczvk.png
# amtws.png  eiaso.png  ikfuk.png  loyyb.png  psrmu.png  tsyuz.png  xekvg.png
# aozyz.png  ejbxv.png  imxpi.png  lrvhz.png  pubdf.png  tszqg.png  xflcd.png
# asjgu.png  ekzda.png  inouq.png  lrvjo.png  pugbm.png  ttnwv.png  xflcg.png
# avdia.png  elucu.png  iodyt.png  lschk.png  putfc.png  ttukf.png  xgfjs.png
# cntfu.png  ghyqk.png  jzzph.png  nsule.png  rtaxw.png  vfexz.png  yzzvn.png
# coqdz.png  gjrgj.png  kddlz.png  ntmgy.png  rttpk.png  vjake.png  zazoc.png
# corko.png  gkxgo.png  keeee.png  nurap.png  rtyse.png  vjbss.png  zbdcg.png
# coznq.png  glmbx.png  ketsx.png  nvrur.png  rvqgu.png  vkhcd.png  zbmts.png
# cuqmx.png  glxtr.png  kgcxy.png  nyixd.png  rvsre.png  vkieq.png  zfjxd.png
# cviby.png  gontu.png  kibrr.png  nysip.png  ryrhr.png  vkqni.png  zigud.png
# cxnah.png  gqamt.png  kjlas.png  oawro.png  ryyui.png  vnjqd.png  ziptw.png
# dcpxj.png  grssc.png  kkzwd.png  obyaz.png  saqko.png  voefp.png  zjccg.png
# dfigq.png  gshwa.png  klgcf.png  ocjlr.png  sbfga.png  vpndx.png  zlqqo.png
# dhwws.png  gsotk.png  klgwv.png  oclfh.png  scujx.png  vqkzz.png  zlxkp.png
# djbyx.png  gssqw.png  kmhsh.png  oesuk.png  scvrv.png  vsige.png  zlyte.png
# djcqe.png  gtpah.png  knhui.png  oeueo.png  sdwzk.png  vtrjh.png  zmbgf.png
# djeyw.png  gully.png  knrtr.png  oewgm.png  sjsqt.png  vwtwv.png  zmjji.png
# djtsv.png  gwfgs.png  knuvd.png  ojpan.png  skbqc.png  vznbe.png  zokfx.png
# dlamq.png  gyucp.png  kobtq.png  okaan.png  slxcn.png  waxrr.png  zpjgu.png
# dlubb.png  hbzvp.png  kpmuf.png  okiws.png  sncxf.png  wayxf.png  zrmrf.png
# dlxou.png  hlysa.png  krloz.png  olnoc.png  spycw.png  wchyp.png  zsxhy.png
# dnpls.png  horpt.png  krmhn.png  onzgs.png  sqsui.png  wduis.png  ztddz.png
# dqeez.png  houlu.png  ksrmu.png  ooxie.png  sqvfr.png  wgdxn.png  zueln.png
# dqhdd.png  hppbe.png  ktuad.png  opiuu.png  sqxpe.png  wiwoo.png  zwzwr.png
# drajr.png  hrlxk.png  kuarv.png  orzcj.png  sqzki.png  wludr.png  zxdww.png
# drbfc.png  htnet.png  kuvbk.png  osppr.png  sscfw.png  wmutj.png  zxfcf.png
# drkib.png  htzjg.png  kvirn.png  owjce.png  svbnn.png  wnsud.png  zydhb.png
# dsnia.png  hvkae.png  kvqrt.png  ownem.png  svpnk.png  wnucp.png
# dwssw.png  hzfvy.png  kvsbz.png  oxvym.png  swcrq.png  woftm.png
# dybgz.png  ibego.png  kxppf.png  pamcm.png  swrmt.png  wogyg.png
# dzbfd.png  ibmsk.png  kzlvj.png  pbhgs.png  syfyh.png  wqjij.png

# %%
# !rm -f image.png

# %%
# !pip install captcha
# Out:
# Collecting captcha
#   Downloading https://files.pythonhosted.org/packages/90/fe/d4ddf1e6576073b5eaea76e9b2afa022c626212a30c871968480be3ccb7b/captcha-0.3-py3-none-any.whl (101kB)
#      |████████████████████████████████| 102kB 4.0MB/s
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from captcha) (7.0.0)
# Installing collected packages: captcha
# Successfully installed captcha-0.3
